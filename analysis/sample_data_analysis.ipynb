# %% [markdown]
# # Exploratory Data Analysis
# This notebook provides an overview of the sample generated dataset and initial insights.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('../data/market_data.csv')
df.head()
# Out:
#     feature1   feature2    feature3  target
# 0  34.396479  32.825109   93.772574       0
# 1  49.690224  30.286324  120.221827       0
# 2  43.790716  31.207874   67.617958       0
# 3  35.354195  32.430863   73.910378       1
# 4  64.119461  28.182833  103.000079       1

# %% [markdown]
# ## Summary Statistics

# %%
df.describe()
# Out:
#          feature1    feature2    feature3      target
# count  200.000000  200.000000  200.000000  200.000000
# mean    49.220980   29.913327   98.083328    0.510000
# std     10.536503    4.569736   20.042094    0.501154
# min     11.901096   19.891746   42.239815    0.000000
# 25%     42.704665   26.661968   87.171688    0.000000
# 50%     48.967140   29.758196   99.844509    1.000000
# 75%     56.857382   33.174089  110.673880    1.000000
# max     83.140753   41.632388  157.444195    1.000000

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Distribution of Features

# %%
df.hist(figsize=(10, 8), bins=20)
plt.tight_layout()
plt.show()
